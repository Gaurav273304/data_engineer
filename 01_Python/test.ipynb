# %%
print('Hello World')
# Out:
# Hello World

# %%
def hello():
    print("how are you")

hello()
# Out:
# how are you

# %%
# add two numbers
def add(x, y):
    return x + y

# %%
x= 10
y=10
print(add(x,y))
# Out:
# 20

# %%
def add()
