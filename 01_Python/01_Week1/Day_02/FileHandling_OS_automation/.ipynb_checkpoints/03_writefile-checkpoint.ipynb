# %%
def write_into_file(userinput,filename):
    with open(filename+".txt","w") as file:
        file.write(username)

userInput=input("Enter your file content")
filename=input("Enter your file name")
write_into_file(username,filename)
# Out:
# Enter your file content I love my India
# Enter your file name aparichit

# %%
# multiple line store
def write_into_file1(userinput,filename):
    with open(filename+".txt","w") as file:
        file.write(username)
file_name = input("Enter filename without extension")
user_inp = ""
while True:
    user_i = input("Enter Data = ")
    if user_i == 'q' or user_i == 'Q':
        break
    user_inp += user_i
    user_inp += "\n"

write_into_file1(username,filename)
# Out:
# Enter filename without extension aparichit1
# Enter Data =  knjk
# Enter Data =  kjkjl
# Enter Data =  hiubghiuhb
# Enter Data =  q
