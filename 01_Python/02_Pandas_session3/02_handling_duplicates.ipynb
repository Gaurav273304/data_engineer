# %%
import pandas as pd
df = pd.read_csv('employees.csv')

df.duplicated().sum()

# df[df.duplicated(keep = False)] # keep = False -> show all the duplicate rows,by default it is 'first' 
                                # which shows only the first occurrence of the duplicate rows.
# Out:
# np.int64(20)

# %%
# df_clean =df.drop_duplicates(keep = 'last')
# df_clean
# df_clean =df.drop_duplicates(keep = False) # drop all the duplicate rows
# df_clean
# Out:
#      emp_id             name   age  gender   department designation    salary  \
# 6      1007     Karan Mishra  35.0    Male  Engineering      Senior   82266.0
# 7      1008   Vivaan Chauhan  27.0  Female           HR   Associate   65792.0
# 8      1009     Nikhil Patel  24.0  Female    Marketing      Senior   85452.0
# 9      1010    Vivaan Bansal  37.0    Male      Support      Senior   94511.0
# 10     1011     Rohan Sharma  28.0  Female  Engineering        Lead   95758.0
# ..      ...              ...   ...     ...          ...         ...       ...
# 500    1501  Pallavi Chauhan  34.0  Female  Engineering      Junior   55135.0
# 501    1502       Geeta Nair  45.0  Female  Engineering      Senior   91113.0
# 502    1503    Aditya Mishra  27.0  Female  Engineering      Junior   55060.0
# 503    1504    Shweta Pillai  41.0  Female        Sales      Senior   88299.0
# 504    1505    Rakesh Chopra  37.0    Male      Support     Manager  137886.0
#
# ...

# %%
df[df.duplicated(keep = False)]
# Out:
#      emp_id           name   age  gender   department designation    salary  \
# 0      1001   Kriti Saxena  33.0    Male  Engineering     Manager  133646.0
# 1      1002    Aadhya Nair  39.0  Female  Engineering      Senior   81835.0
# 2      1003  Bhavna Saxena  56.0    Male  Engineering      Intern   42051.0
# 3      1004     Rohan Shah  51.0    Male        Sales   Associate   72798.0
# 4      1005     Geeta Nair  45.0  Female  Engineering      Senior   91113.0
# 5      1006    Rahul Gupta  51.0    Male      Product          VP  209477.0
# 480    1481   Aadhya Yadav  26.0  Female   Operations      Junior   30192.0
# 481    1482   Deepak Reddy  32.0    Male      Finance     Manager  128160.0
# 482    1483   Shreya Yadav  33.0    Male      PRODUCT        Lead   88645.0
# 483    1484      Anvi Shah  31.0    Male      Product        Lead   97816.0
# 484    1485    Varun Yadav  29.0    Male   Operations      Intern   21314.0
# ...

# %%
df_clean = df.drop_duplicates(keep = 'first')
df_clean
# Out:
#      emp_id             name   age  gender   department designation    salary  \
# 0      1001     Kriti Saxena  33.0    Male  Engineering     Manager  133646.0
# 1      1002      Aadhya Nair  39.0  Female  Engineering      Senior   81835.0
# 2      1003    Bhavna Saxena  56.0    Male  Engineering      Intern   42051.0
# 3      1004       Rohan Shah  51.0    Male        Sales   Associate   72798.0
# 4      1005       Geeta Nair  45.0  Female  Engineering      Senior   91113.0
# ..      ...              ...   ...     ...          ...         ...       ...
# 500    1501  Pallavi Chauhan  34.0  Female  Engineering      Junior   55135.0
# 501    1502       Geeta Nair  45.0  Female  Engineering      Senior   91113.0
# 502    1503    Aditya Mishra  27.0  Female  Engineering      Junior   55060.0
# 503    1504    Shweta Pillai  41.0  Female        Sales      Senior   88299.0
# 504    1505    Rakesh Chopra  37.0    Male      Support     Manager  137886.0
#
# ...

# %%
#check if there are employees with same name and email

df[df.duplicated(subset = ['name', 'email'], keep = False)]
# Out:
#      emp_id           name   age  gender   department designation    salary  \
# 0      1001   Kriti Saxena  33.0    Male  Engineering     Manager  133646.0
# 1      1002    Aadhya Nair  39.0  Female  Engineering      Senior   81835.0
# 2      1003  Bhavna Saxena  56.0    Male  Engineering      Intern   42051.0
# 3      1004     Rohan Shah  51.0    Male        Sales   Associate   72798.0
# 4      1005     Geeta Nair  45.0  Female  Engineering      Senior   91113.0
# ..      ...            ...   ...     ...          ...         ...       ...
# 520    1490   Meera Chopra  29.0  Female   Operations    Director  160655.0
# 521    1491    Ayaan Joshi  30.0    Male  Engineering      Senior   80129.0
# 522    1492     Gaurav Rao  36.0    Male      Product   Associate   54359.0
# 523    1493   Sai Kulkarni  39.0  Female      Product   Associate   48893.0
# 524    1494   Suresh Verma  41.0  Female  Engineering      Senior   71811.0
#
#           city   join_date  experience_years  rating  \
# ...
