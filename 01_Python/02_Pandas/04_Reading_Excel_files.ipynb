# %%
import pandas as pd

# %%
df = pd.read_excel("company_data.xlsx", sheet_name=2)
df.head(10)
# Out:
#    project_id          project_name  dept_id  start_date    end_date  \
# 0        2001      Data Pipeline v2      107  2024-01-01  2024-02-25
# 1        2002           CRM Upgrade      103  2024-01-16  2024-05-11
# 2        2003     Brand Campaign Q1      102  2024-01-31  2024-06-01
# 3        2004       Employee Portal      107  2024-02-15  2024-06-25
# 4        2005    Budget Forecasting      105  2024-03-01  2024-06-09
# 5        2006  Warehouse Automation      108  2024-03-16  2024-09-01
# 6        2007   Mobile App Redesign      106  2024-03-31  2024-08-02
# 7        2008            Chatbot v3      108  2024-04-15  2024-09-09
# 8        2009           API Gateway      101  2024-04-30  2024-10-24
# 9        2010       Sales Dashboard      101  2024-05-15  2024-10-10
#
#       status  budget_lakhs
# 0   Planning            88
# 1     Active            15
# 2  Completed            42
# 3  Completed            64
# 4     Active            28
# 5    On Hold            86
# ...
