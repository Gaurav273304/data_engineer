# %%
import pandas as pd
s = pd.Series([1,2,3,4,5])
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#create a series with custom index
s2 = pd.Series([1,2,3,4,5],index = ['a','b','c','d','e'])
print(s2)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
#from a dictionary
s3 = pd.Series({'name':'gaurav','age':30,'city':'delhi'})
print(s3)
# Out:
# name    gaurav
# age         30
# city     delhi
# dtype: object
