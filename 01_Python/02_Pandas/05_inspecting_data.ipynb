# %%
import pandas as pd

# %%
df = pd.read_excel("company_data.xlsx", sheet_name=0)
# print(df.shape)
# print(len(df))
# print(df.columns)
# print(df.columns.tolist())
# print(df.dtypes)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   emp_id            505 non-null    int64
#  1   name              505 non-null    object
#  2   age               490 non-null    float64
#  3   gender            505 non-null    object
#  4   department        497 non-null    object
#  5   designation       505 non-null    object
#  6   salary            485 non-null    float64
#  7   city              495 non-null    object
#  8   join_date         505 non-null    object
#  9   experience_years  505 non-null    int64
#  10  rating            480 non-null    float64
#  11  email             505 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 47.5+ KB
# None

# %%
#peeking at rows
# print(df.head(6))
# print(df.tail(6))
# df.sample(frac=0.1)

df.describe(include = "int64")
# Out:
#             emp_id  experience_years
# count   505.000000        505.000000
# mean   1253.000000         17.768317
# std     145.925209         10.237448
# min    1001.000000          0.000000
# 25%    1127.000000          9.000000
# 50%    1253.000000         18.000000
# 75%    1379.000000         26.000000
# max    1505.000000         35.000000

# %%
# df['department'].value_counts()
#percentage of each department
df['department'].value_counts(normalize=True)
# Out:
# department
# Engineering    0.271630
# Sales          0.138833
# Product        0.130785
# Marketing      0.100604
# HR             0.090543
# Finance        0.090543
# Operations     0.088531
# Support        0.078471
# SUPPORT        0.004024
# FINANCE        0.002012
# ENGINEERING    0.002012
# PRODUCT        0.002012
# Name: proportion, dtype: float64

# %%
#unique values in department column
print(df['department'].unique())

df.nunique()
# Out:
# ['Engineering' 'Sales' 'Product' 'HR' 'Marketing' 'Support' 'Finance'
#  'Operations' nan 'FINANCE' 'SUPPORT' 'ENGINEERING' 'PRODUCT']
# emp_id              505
# name                462
# age                  36
# gender                2
# department           12
# designation           8
# salary              478
# city                 19
# join_date           480
# experience_years     36
# rating               36
# email               462
# dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 #find perticular department value counts
# ----> 2 print(df(df['department']== 'Engineering').value_counts(normalize=True))
#
# TypeError: 'DataFrame' object is not callable
