# %% [markdown]
# ##### Q1. Remove duplicates from list (without using set)

# %%
list1 = [1,2,3,4,5,2,4]
list2 = []
for i in list1:
    if i not in list2:
        list2.append(i)
print(list2)
# Out:
# [1, 2, 3, 4, 5]

# %%
unique_comp = [list1[i] for i in range(len(list1)) if list1[i] not in list1[:i]]
print(unique_comp)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ##### Generate dictionary of word counts (from a sentence)

# %%
from collections import Counter
sentence = "data engineering is fun and data is powerful"
words_count = Counter(sentence.split())
print(words_count)
# Out:
# Counter({'data': 2,
#          'is': 2,
#          'engineering': 1,
#          'fun': 1,
#          'and': 1,
#          'powerful': 1})
